# %% [markdown]
# <a href="https://colab.research.google.com/github/Momegaii/MS_Quantum_research/blob/main/omega_inside.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this sine wave experment Will be on the inside of the omega stars and moving

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate x values
x = np.linspace(0, 3 * np.pi*2, 1000)

# Generate y values for a basic sine wave (Amplitude=1, Frequency=1, Phase Shift=0, Vertical Shift=0)
y = np.sin(x) / 0.006

x2 = np.linspace(0, 3 * np.pi *2, 1000)
y2 = np.sin(x2) /0.009

x3 = np.linspace(0, 3 * np.pi*2, 1000)
y3 = np.sin(x3) /0.008

x4 = np.linspace(0, 3 * np.pi*2, 1000)
y4 = np.sin(x4) /0.007

x5 = np.linspace(0, 3 * np.pi*2, 1000)
y5 = np.sin(x5) /-0.09

x6 = np.linspace(0, 3 * np.pi*2, 1000)
y6 = np.sin(x6) /-0.08

x7 = np.linspace(0, 3 * np.pi*2, 1000)
y7 = np.sin(x7) /-0.07

x8 = np.linspace(0, 3 * np.pi*2, 1000)
y8 = np.sin(x8) /-0.06

x9 = np.linspace(0, 3 * np.pi*2, 1000)
y9 = np.sin(x9) /-0.05

x10 = np.linspace(0, 3 * np.pi*2, 1000)
y10 = np.sin(x10) /-0.04

x11 = np.linspace(0, 3 * np.pi*2, 1000)
y11 = np.sin(x11) /-0.03

x12 = np.linspace(0, 3 * np.pi*2, 1000)
y12 = np.sin(x12) /-0.02

x13 = np.linspace(0, 3 * np.pi*2, 1000)
y13 = np.sin(x13) /-0.01


# Generate x values
x14 = np.linspace(0, 3 * np.pi*2, 1000)

# Generate y values for a basic sine wave (Amplitude=1, Frequency=1, Phase Shift=0, Vertical Shift=0)
y14 = np.sin(x) / -0.006

x15 = np.linspace(0, 3 * np.pi *2, 1000)
y15 = np.sin(x2) /-0.009

x16 = np.linspace(0, 3 * np.pi*2, 1000)
y16 = np.sin(x3) /-0.008

x17 = np.linspace(0, 3 * np.pi*2, 1000)
y17 = np.sin(x4) /-0.007
# Plot the sine wave
# Set the figure and axes background color to black
fig, ax = plt.subplots()
fig.patch.set_facecolor('black')
ax.set_facecolor('black')

# Plot the sine waves with green color
ax.plot(x, y, color='lime', label='Sine 1')
ax.plot(x2, y2, color='lime', label='Sine 2')
ax.plot(x3, y3, color='lime', label='Sine 3')
ax.plot(x4, y4, color='lime', label='Sine 4')
ax.plot(x5, y5, color='lime', label='Sine 5')
ax.plot(x6, y6, color='lime', label='Sine 6')
ax.plot(x7, y7, color='lime', label='Sine 7')
ax.plot(x8, y8, color='lime', label='Sine 8')
ax.plot(x9, y9, color='lime', label='Sine 9')
ax.plot(x10, y10, color='lime', label='Sine 10')
ax.plot(x11, y11, color='lime', label='Sine 11')
ax.plot(x12, y12, color='lime', label='Sine 12')
ax.plot(x13, y13, color='lime', label='Sine 13')
ax.plot(x14, y14, color='lime', label='Sine 14')
ax.plot(x15, y15, color='lime', label='Sine 15')
ax.plot(x16, y16, color='lime', label='Sine 16')
ax.plot(x17, y17, color='lime', label='Sine 17')

ax.set_xlabel('x', color='white') # Set label color to white for visibility
ax.set_ylabel('sin(x)', color='white') # Set label color to white for visibility
ax.set_title('omega aves Sine Wave', color='white') # Set title color to white for visibility
ax.tick_params(axis='x', colors='white') # Set tick color to white for visibility
ax.tick_params(axis='y', colors='white') # Set tick color to white for visibility

plt.show()
